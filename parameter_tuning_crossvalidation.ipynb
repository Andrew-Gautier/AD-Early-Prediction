# %% [markdown]
# # XGBoost Grid Search
#
# This notebook performs a basic experiment for hyperparameter tuning for XGBoost models using grid search.

# %%
# Import libraries
import pandas as pd
from xgboost_grid_search import train_best_model

# %%
files = {'Dataset_1/2visit_CN_MCI.csv','Dataset_1/2visit_MCI_AD.csv', 'Dataset_1/3visit_CN_MCI.csv','Dataset_1/3visit_MCI_AD.csv', 'Dataset_1/4visit_CN_MCI.csv','Dataset_1/4visit_MCI_AD.csv'
         'Dataset_1/5visit_CN_MCI.csv','Dataset_1/5visit_MCI_AD.csv'}

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

# %%
# Batch grid search across datasets and progression types, saving artifacts and reports
import os
from datetime import datetime
from xgboost_grid_search import train_best_model

# Datasets and their progression type
files = [
    ("Dataset_1/2visit_CN_MCI.csv", "MCI"),
    ("Dataset_1/2visit_MCI_AD.csv", "AD"),
    ("Dataset_1/3visit_CN_MCI.csv", "MCI"),
    ("Dataset_1/3visit_MCI_AD.csv", "AD"),
    ("Dataset_1/4visit_CN_MCI.csv", "MCI"),
    ("Dataset_1/4visit_MCI_AD.csv", "AD"),
    ("Dataset_1/5visit_CN_MCI.csv", "MCI"),
    ("Dataset_1/5visit_MCI_AD.csv", "AD"),
]

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

results_dir = "grid_results"
os.makedirs(results_dir, exist_ok=True)

for path, prog in files:
    try:
        df = pd.read_csv(path)
        base = os.path.splitext(os.path.basename(path))[0]
        csv_out = os.path.join(results_dir, f"{base}_{prog}_cv_scores.csv")
        model_base = f"{base}"
        print(f"\n=== Running grid search for {base} ({prog}) ===")
        model, cols = train_best_model(
            df,
            progression_type=prog,
            param_grid=param_grid,
            csv_path=csv_out,
            save_dir="saved_models",
            model_base_name=model_base,
            save_artifacts=True,
        )
    except Exception as e:
        print(f"Error processing {path}: {e}")
# Out:
# === Running grid search for 2visit_CN_MCI (MCI) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       209
#            1       0.31      0.25      0.28        16
#
#     accuracy                           0.91       225
#    macro avg       0.63      0.60      0.61       225
# weighted avg       0.90      0.91      0.90       225
#
#
# ROC AUC Score: 0.7593
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       209
#            1       0.31      0.25      0.28        16
#
#     accuracy                           0.91       225
#    macro avg       0.63      0.60      0.61       225
# weighted avg       0.90      0.91      0.90       225
#
#
# ROC AUC Score: 0.7593
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.907 (CI: 0.867, 0.947)
# - Precision (macro): 0.626 (CI: 0.507, 0.768)
# - Recall (macro): 0.603 (CI: 0.506, 0.720)
# - F1 (macro): 0.613 (CI: 0.505, 0.722)
# - ROC AUC: 0.759 (CI: 0.604, 0.887)
#
# Saved artifacts:
# - Model:   saved_models/2visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/2visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/2visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/2visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 2visit_MCI_AD (AD) ===
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.907 (CI: 0.867, 0.947)
# - Precision (macro): 0.626 (CI: 0.507, 0.768)
# - Recall (macro): 0.603 (CI: 0.506, 0.720)
# - F1 (macro): 0.613 (CI: 0.505, 0.722)
# - ROC AUC: 0.759 (CI: 0.604, 0.887)
#
# Saved artifacts:
# - Model:   saved_models/2visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/2visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/2visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/2visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 2visit_MCI_AD (AD) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.73      0.68        45
#            1       0.68      0.57      0.62        44
#
#     accuracy                           0.65        89
#    macro avg       0.66      0.65      0.65        89
# weighted avg       0.65      0.65      0.65        89
#
#
# ROC AUC Score: 0.7263
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.73      0.68        45
#            1       0.68      0.57      0.62        44
#
#     accuracy                           0.65        89
#    macro avg       0.66      0.65      0.65        89
# weighted avg       0.65      0.65      0.65        89
#
#
# ROC AUC Score: 0.7263
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.652 (CI: 0.551, 0.753)
# - Precision (macro): 0.655 (CI: 0.556, 0.757)
# - Recall (macro): 0.651 (CI: 0.554, 0.752)
# - F1 (macro): 0.649 (CI: 0.549, 0.746)
# - ROC AUC: 0.726 (CI: 0.612, 0.830)
#
# Saved artifacts:
# - Model:   saved_models/2visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/2visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/2visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/2visit_MCI_AD_report_AD.txt
#
# === Running grid search for 3visit_CN_MCI (MCI) ===
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.652 (CI: 0.551, 0.753)
# - Precision (macro): 0.655 (CI: 0.556, 0.757)
# - Recall (macro): 0.651 (CI: 0.554, 0.752)
# - F1 (macro): 0.649 (CI: 0.549, 0.746)
# - ROC AUC: 0.726 (CI: 0.612, 0.830)
#
# Saved artifacts:
# - Model:   saved_models/2visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/2visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/2visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/2visit_MCI_AD_report_AD.txt
#
# === Running grid search for 3visit_CN_MCI (MCI) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       115
#            1       0.60      0.60      0.60        10
#
#     accuracy                           0.94       125
#    macro avg       0.78      0.78      0.78       125
# weighted avg       0.94      0.94      0.94       125
#
#
# ROC AUC Score: 0.9757
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       115
#            1       0.60      0.60      0.60        10
#
#     accuracy                           0.94       125
#    macro avg       0.78      0.78      0.78       125
# weighted avg       0.94      0.94      0.94       125
#
#
# ROC AUC Score: 0.9757
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.936 (CI: 0.888, 0.976)
# - Precision (macro): 0.783 (CI: 0.633, 0.928)
# - Recall (macro): 0.783 (CI: 0.628, 0.944)
# - F1 (macro): 0.783 (CI: 0.633, 0.908)
# - ROC AUC: 0.976 (CI: 0.948, 0.996)
#
# Saved artifacts:
# - Model:   saved_models/3visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/3visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/3visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/3visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 3visit_MCI_AD (AD) ===
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.936 (CI: 0.888, 0.976)
# - Precision (macro): 0.783 (CI: 0.633, 0.928)
# - Recall (macro): 0.783 (CI: 0.628, 0.944)
# - F1 (macro): 0.783 (CI: 0.633, 0.908)
# - ROC AUC: 0.976 (CI: 0.948, 0.996)
#
# Saved artifacts:
# - Model:   saved_models/3visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/3visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/3visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/3visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 3visit_MCI_AD (AD) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.45      0.59      0.51        17
#            1       0.82      0.72      0.77        43
#
#     accuracy                           0.68        60
#    macro avg       0.64      0.65      0.64        60
# weighted avg       0.71      0.68      0.69        60
#
#
# ROC AUC Score: 0.7332
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.45      0.59      0.51        17
#            1       0.82      0.72      0.77        43
#
#     accuracy                           0.68        60
#    macro avg       0.64      0.65      0.64        60
# weighted avg       0.71      0.68      0.69        60
#
#
# ROC AUC Score: 0.7332
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.683 (CI: 0.567, 0.800)
# - Precision (macro): 0.635 (CI: 0.512, 0.757)
# - Recall (macro): 0.655 (CI: 0.514, 0.789)
# - F1 (macro): 0.639 (CI: 0.508, 0.764)
# - ROC AUC: 0.733 (CI: 0.594, 0.865)
#
# Saved artifacts:
# - Model:   saved_models/3visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/3visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/3visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/3visit_MCI_AD_report_AD.txt
#
# === Running grid search for 4visit_CN_MCI (MCI) ===
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.683 (CI: 0.567, 0.800)
# - Precision (macro): 0.635 (CI: 0.512, 0.757)
# - Recall (macro): 0.655 (CI: 0.514, 0.789)
# - F1 (macro): 0.639 (CI: 0.508, 0.764)
# - ROC AUC: 0.733 (CI: 0.594, 0.865)
#
# Saved artifacts:
# - Model:   saved_models/3visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/3visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/3visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/3visit_MCI_AD_report_AD.txt
#
# === Running grid search for 4visit_CN_MCI (MCI) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       111
#            1       0.33      0.57      0.42         7
#
#     accuracy                           0.91       118
#    macro avg       0.65      0.75      0.69       118
# weighted avg       0.93      0.91      0.92       118
#
#
# ROC AUC Score: 0.9459
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       111
#            1       0.33      0.57      0.42         7
#
#     accuracy                           0.91       118
#    macro avg       0.65      0.75      0.69       118
# weighted avg       0.93      0.91      0.92       118
#
#
# ROC AUC Score: 0.9459
# Bootstrap classification metrics: attempted=1000, auc_valid=999, auc_skipped=1
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.907 (CI: 0.856, 0.949)
# - Precision (macro): 0.653 (CI: 0.527, 0.804)
# - Recall (macro): 0.750 (CI: 0.543, 0.957)
# - F1 (macro): 0.685 (CI: 0.531, 0.820)
# - ROC AUC: 0.946 (CI: 0.888, 0.986)
#
# Saved artifacts:
# - Model:   saved_models/4visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/4visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/4visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/4visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 4visit_MCI_AD (AD) ===
# Bootstrap classification metrics: attempted=1000, auc_valid=999, auc_skipped=1
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.907 (CI: 0.856, 0.949)
# - Precision (macro): 0.653 (CI: 0.527, 0.804)
# - Recall (macro): 0.750 (CI: 0.543, 0.957)
# - F1 (macro): 0.685 (CI: 0.531, 0.820)
# - ROC AUC: 0.946 (CI: 0.888, 0.986)
#
# Saved artifacts:
# - Model:   saved_models/4visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/4visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/4visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/4visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 4visit_MCI_AD (AD) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.30      0.43      0.35         7
#            1       0.90      0.83      0.86        42
#
#     accuracy                           0.78        49
#    macro avg       0.60      0.63      0.61        49
# weighted avg       0.81      0.78      0.79        49
#
#
# ROC AUC Score: 0.7619
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.30      0.43      0.35         7
#            1       0.90      0.83      0.86        42
#
#     accuracy                           0.78        49
#    macro avg       0.60      0.63      0.61        49
# weighted avg       0.81      0.78      0.79        49
#
#
# ROC AUC Score: 0.7619
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.776 (CI: 0.653, 0.898)
# - Precision (macro): 0.599 (CI: 0.453, 0.768)
# - Recall (macro): 0.631 (CI: 0.433, 0.838)
# - F1 (macro): 0.609 (CI: 0.443, 0.776)
# - ROC AUC: 0.762 (CI: 0.581, 0.918)
#
# Saved artifacts:
# - Model:   saved_models/4visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/4visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/4visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/4visit_MCI_AD_report_AD.txt
#
# === Running grid search for 5visit_CN_MCI (MCI) ===
# Bootstrap classification metrics: attempted=1000, auc_valid=1000, auc_skipped=0
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.776 (CI: 0.653, 0.898)
# - Precision (macro): 0.599 (CI: 0.453, 0.768)
# - Recall (macro): 0.631 (CI: 0.433, 0.838)
# - F1 (macro): 0.609 (CI: 0.443, 0.776)
# - ROC AUC: 0.762 (CI: 0.581, 0.918)
#
# Saved artifacts:
# - Model:   saved_models/4visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/4visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/4visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/4visit_MCI_AD_report_AD.txt
#
# === Running grid search for 5visit_CN_MCI (MCI) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        86
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.97        90
#    macro avg       0.98      0.62      0.69        90
# weighted avg       0.97      0.97      0.96        90
#
#
# ROC AUC Score: 0.8110
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        86
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.97        90
#    macro avg       0.98      0.62      0.69        90
# weighted avg       0.97      0.97      0.96        90
#
#
# ROC AUC Score: 0.8110
# Bootstrap classification metrics: attempted=1000, auc_valid=976, auc_skipped=24
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.967 (CI: 0.922, 1.000)
# - Precision (macro): 0.983 (CI: 0.467, 1.000)
# - Recall (macro): 0.625 (CI: 0.500, 1.000)
# - F1 (macro): 0.691 (CI: 0.483, 1.000)
# - ROC AUC: 0.811 (CI: 0.496, 1.000)
#
# Saved artifacts:
# - Model:   saved_models/5visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/5visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/5visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/5visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 5visit_MCI_AD (AD) ===
# Bootstrap classification metrics: attempted=1000, auc_valid=976, auc_skipped=24
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.967 (CI: 0.922, 1.000)
# - Precision (macro): 0.983 (CI: 0.467, 1.000)
# - Recall (macro): 0.625 (CI: 0.500, 1.000)
# - F1 (macro): 0.691 (CI: 0.483, 1.000)
# - ROC AUC: 0.811 (CI: 0.496, 1.000)
#
# Saved artifacts:
# - Model:   saved_models/5visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models/5visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models/5visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models/5visit_CN_MCI_report_MCI.txt
#
# === Running grid search for 5visit_MCI_AD (AD) ===
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.96      0.96      0.96        26
#
#     accuracy                           0.93        28
#    macro avg       0.73      0.73      0.73        28
# weighted avg       0.93      0.93      0.93        28
#
#
# ROC AUC Score: 0.8077
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.96      0.96      0.96        26
#
#     accuracy                           0.93        28
#    macro avg       0.73      0.73      0.73        28
# weighted avg       0.93      0.93      0.93        28
#
#
# ROC AUC Score: 0.8077
# Bootstrap classification metrics: attempted=1000, auc_valid=870, auc_skipped=130
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.929 (CI: 0.821, 1.000)
# - Precision (macro): 0.731 (CI: 0.460, 1.000)
# - Recall (macro): 0.731 (CI: 0.446, 1.000)
# - F1 (macro): 0.731 (CI: 0.462, 1.000)
# - ROC AUC: 0.808 (CI: 0.519, 1.000)
#
# Saved artifacts:
# - Model:   saved_models/5visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/5visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/5visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/5visit_MCI_AD_report_AD.txt
# Bootstrap classification metrics: attempted=1000, auc_valid=870, auc_skipped=130
#
# Bootstrap 95% CI (n=1000):
# - Accuracy: 0.929 (CI: 0.821, 1.000)
# - Precision (macro): 0.731 (CI: 0.460, 1.000)
# - Recall (macro): 0.731 (CI: 0.446, 1.000)
# - F1 (macro): 0.731 (CI: 0.462, 1.000)
# - ROC AUC: 0.808 (CI: 0.519, 1.000)
#
# Saved artifacts:
# - Model:   saved_models/5visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models/5visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models/5visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models/5visit_MCI_AD_report_AD.txt

# %%
from xgboost_grid_search import preprocess_data, create_delta_features
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTENC
import numpy as np


path, prog = "Dataset_1/5visit_MCI_AD.csv", "AD"
df = pd.read_csv(path)
processed_df, _, _ = preprocess_data(create_delta_features(df), prog)

X = processed_df.drop('target', axis=1)
y = processed_df['target']

# Identify categorical column indices BEFORE transforms
categorical_cols = ['SEX', 'NACCFAM', 'CVHATT', 'CVAFIB', 'DIABETES', 
                    'HYPERCHO', 'HYPERTEN', 'B12DEF', 'DEPD', 'ANX', 'NACCTBI', 'RACE']
categorical_cols = [col for col in categorical_cols if col in X.columns.tolist()]
cat_indices = [X.columns.get_loc(col) for col in categorical_cols]

# 1. Impute (use most_frequent to keep categoricals as ints)
imputer = SimpleImputer(strategy='most_frequent')
X_imputed = imputer.fit_transform(X)

# 2. Scale BEFORE SMOTENC (SMOTENC handles categorical cols internally)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# 3. Apply SMOTENC on scaled data
#    Pass categorical_features as keyword; use lower k_neighbors if minority class is small
sm = SMOTENC(categorical_features=cat_indices, k_neighbors=3, random_state=42)
X_resampled, y_resampled = sm.fit_resample(X_scaled, y)

# Check results
print(f"Total samples: {len(y_resampled)}")
print(f"Class 0: {(y_resampled == 0).sum()}")
print(f"Class 1: {(y_resampled == 1).sum()}")
# Save resampled data to CSV with highlighting of synthetic rows
df_resampled = pd.DataFrame(X_resampled, columns=X.columns)
df_resampled['target'] = y_resampled

# Add a column to mark synthetic vs original rows
# Original rows: first 138 (length of original y)
# Synthetic rows: after index 138
df_resampled['is_synthetic'] = ['Original'] * len(y) + ['SMOTE_Generated'] * (len(y_resampled) - len(y))

df_resampled.to_csv('smote_resampled_data.csv', index=False)
print(f"\nResampled data saved to 'smote_resampled_data.csv'")
print(f"Original samples: {len(y)}")
print(f"SMOTE generated samples: {len(y_resampled) - len(y)}")
print("\nSample of SMOTE-generated instances:")
print(df_resampled[df_resampled['is_synthetic'] == 'SMOTE_Generated'].head(10))
# Out:
# Total samples: 254
# Class 0: 127
# Class 1: 127
#
# Resampled data saved to 'smote_resampled_data.csv'
# Original samples: 138
# SMOTE generated samples: 116
#
# Sample of SMOTE-generated instances:
#           SEX      EDUC   ALCOHOL  NACCFAM  CVHATT    CVAFIB  DIABETES  \
# 138 -0.929981 -1.140183 -0.204808  0.83887     0.0 -0.279508 -0.470360
# 139  1.075291 -0.677870 -0.204808  0.83887     0.0 -0.279508 -0.470360
# 140 -0.929981  0.212983 -0.204808  0.83887     0.0 -0.279508 -0.470360
# 141 -0.929981 -0.733847 -0.204808  0.83887     0.0 -0.279508 -0.470360
# 142 -0.929981 -0.930840 -0.204808  0.83887     0.0 -0.279508 -0.470360
# 143  1.075291 -0.281641  3.433847  0.83887     0.0 -0.279508  2.126029
# 144 -0.929981 -0.210307 -0.204808  0.83887     0.0 -0.279508 -0.470360
# 145 -0.929981  0.560667 -0.204808  0.83887     0.0 -0.279508 -0.470360
# 146  1.075291 -0.537461  1.786694  0.83887     0.0 -0.279508  2.126029
# 147  1.075291 -0.930524  5.444951  0.83887     0.0 -0.279508  2.126029
#
#      HYPERCHO  HYPERTEN    B12DEF  ...  TRAVEL_V5  TRAVEL_delta_V2-V1  \
# 138  0.753778  0.851469 -0.248069  ...  -1.547276           -0.349640
# 139  0.753778  0.851469 -0.248069  ...  -1.075348           -0.349640
# 140 -1.326650  0.851469 -0.248069  ...  -1.547276           -0.349640
# 141  0.753778 -1.174440 -0.248069  ...  -1.000804           -0.349640
# 142  0.753778 -1.174440 -0.248069  ...  -0.738473           -0.349640
# 143 -1.326650  0.851469 -0.248069  ...  -1.547276           -1.071938
# 144  0.753778  0.851469 -0.248069  ...  -1.547276           -0.349640
# 145  0.753778  0.851469 -0.248069  ...  -1.547276           -0.349640
# 146 -1.326650  0.851469 -0.248069  ...  -1.547276           -0.744966
# 147 -1.326650  0.851469 -0.248069  ...  -1.547276           -1.471155
#
#      TRAVEL_delta_V3-V1  TRAVEL_delta_V4-V1  TRAVEL_delta_V5-V1  TRAVEL_slope  \
# 138           -0.436828           -0.764215           -0.988317     -0.929430
# 139           -0.436828           -1.248749           -0.988317     -1.099877
# 140           -0.436828           -0.764215           -0.988317     -0.929430
# 141           -0.436828           -1.325283           -1.517921     -1.521539
# 142           -0.436828           -1.594622           -1.676458     -1.734450
# 143           -1.015988           -1.298749           -1.492876     -1.305501
# 144           -0.436828           -0.764215           -0.988317     -0.929430
# 145           -0.436828           -0.764215           -0.988317     -0.929430
# 146           -0.753813           -1.056775           -1.264471     -1.135261
# 147           -1.336094           -1.594189           -1.771747     -1.513358
#
#      TRAVEL_mean  TRAVEL_max  target     is_synthetic
# 138    -1.287200   -1.618189       0  SMOTE_Generated
# 139    -0.771488   -1.135599       0  SMOTE_Generated
# 140    -1.287200   -1.618189       0  SMOTE_Generated
# 141    -0.092857   -0.500555       0  SMOTE_Generated
# 142     0.372575   -0.065016       0  SMOTE_Generated
# 143    -1.144967   -1.085799       0  SMOTE_Generated
# 144    -1.287200   -1.618189       0  SMOTE_Generated
# 145    -1.287200   -1.618189       0  SMOTE_Generated
# 146    -1.209354   -1.326802       0  SMOTE_Generated
# 147    -1.066355   -0.791545       0  SMOTE_Generated
#
# [10 rows x 199 columns]

# %% [markdown]
# ## Experiment #2
#
# What's changed:
# 1. SMOTE for synthetic oversampling within training folds.
# 2. Additional patients added to 5 visit cohort
# 3. GDS and categorical longitudinal.
# 3. Hearing and vision variables changed.
# 4. MMSE imputation corrected.

# %%
# Experiment #2: Dataset_2 with post-split MMSE imputation + SMOTENC
# Reload module to pick up changes
import importlib
import xgboost_grid_search
importlib.reload(xgboost_grid_search)
from xgboost_grid_search import train_best_model

import os
import pandas as pd

# Dataset_2 files (MMSE not pre-imputed; will be imputed post-split)
files = [
    ("Dataset_2/2visit_CN_MCI.csv", "MCI"),
    ("Dataset_2/2visit_MCI_AD.csv", "AD"),
    ("Dataset_2/3visit_CN_MCI.csv", "MCI"),
    ("Dataset_2/3visit_MCI_AD.csv", "AD"),
    ("Dataset_2/4visit_CN_MCI.csv", "MCI"),
    ("Dataset_2/4visit_MCI_AD.csv", "AD"),
    ("Dataset_2/5visit_CN_MCI.csv", "MCI"),
    ("Dataset_2/5visit_MCI_AD.csv", "AD"),
]

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

results_dir = "grid_results"
os.makedirs(results_dir, exist_ok=True)

for path, prog in files:
    try:
        df = pd.read_csv(path)
        base = os.path.splitext(os.path.basename(path))[0]
        csv_out = os.path.join(results_dir, f"{base}_{prog}_cv_scores.csv")
        model_base = f"{base}"
        print(f"\n{'='*60}")
        print(f"=== Running grid search for {base} ({prog}) ===")
        print(f"{'='*60}")
        model, cols = train_best_model(
            df,
            progression_type=prog,
            param_grid=param_grid,
            csv_path=csv_out,
            save_dir="saved_models_2",
            model_base_name=model_base,
            save_artifacts=True,
        )
    except Exception as e:
        import traceback
        print(f"Error processing {path}: {e}")
        traceback.print_exc()
# Out:
# ============================================================
# === Running grid search for 2visit_CN_MCI (MCI) ===
# ============================================================
# No MMSE NaN values found; skipping MMSE imputation.
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 900 -> 1670 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       209
#            1       0.35      0.44      0.39        16
#
#     accuracy                           0.90       225
#    macro avg       0.65      0.69      0.67       225
# weighted avg       0.91      0.90      0.91       225
#
#
# ROC AUC Score: 0.6953
# SMOTE resampling: 900 -> 1670 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       209
#            1       0.35      0.44      0.39        16
#
#     accuracy                           0.90       225
#    macro avg       0.65      0.69      0.67       225
# weighted avg       0.91      0.90      0.91       225
#
#
# ROC AUC Score: 0.6953
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.902 (CI: 0.862, 0.942)
# - Precision (macro): 0.653 (CI: 0.548, 0.764)
# - Recall (macro): 0.688 (CI: 0.560, 0.822)
# - F1 (macro): 0.668 (CI: 0.551, 0.772)
# - ROC AUC: 0.695 (CI: 0.514, 0.852)
#
# Saved artifacts:
# - Model:   saved_models_2/2visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/2visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/2visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models_2/2visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 2visit_MCI_AD (AD) ===
# ============================================================
# No MMSE NaN values found; skipping MMSE imputation.
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.902 (CI: 0.862, 0.942)
# - Precision (macro): 0.653 (CI: 0.548, 0.764)
# - Recall (macro): 0.688 (CI: 0.560, 0.822)
# - F1 (macro): 0.668 (CI: 0.551, 0.772)
# - ROC AUC: 0.695 (CI: 0.514, 0.852)
#
# Saved artifacts:
# - Model:   saved_models_2/2visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/2visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/2visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models_2/2visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 2visit_MCI_AD (AD) ===
# ============================================================
# No MMSE NaN values found; skipping MMSE imputation.
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 352 -> 352 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.73      0.68        45
#            1       0.68      0.57      0.62        44
#
#     accuracy                           0.65        89
#    macro avg       0.66      0.65      0.65        89
# weighted avg       0.65      0.65      0.65        89
#
#
# ROC AUC Score: 0.7242
# SMOTE resampling: 352 -> 352 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.73      0.68        45
#            1       0.68      0.57      0.62        44
#
#     accuracy                           0.65        89
#    macro avg       0.66      0.65      0.65        89
# weighted avg       0.65      0.65      0.65        89
#
#
# ROC AUC Score: 0.7242
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.652 (CI: 0.551, 0.742)
# - Precision (macro): 0.655 (CI: 0.555, 0.753)
# - Recall (macro): 0.651 (CI: 0.554, 0.743)
# - F1 (macro): 0.649 (CI: 0.549, 0.741)
# - ROC AUC: 0.724 (CI: 0.609, 0.828)
#
# Saved artifacts:
# - Model:   saved_models_2/2visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/2visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/2visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models_2/2visit_MCI_AD_report_AD.txt
#
# ============================================================
# === Running grid search for 3visit_CN_MCI (MCI) ===
# ============================================================
# No MMSE NaN values found; skipping MMSE imputation.
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.652 (CI: 0.551, 0.742)
# - Precision (macro): 0.655 (CI: 0.555, 0.753)
# - Recall (macro): 0.651 (CI: 0.554, 0.743)
# - F1 (macro): 0.649 (CI: 0.549, 0.741)
# - ROC AUC: 0.724 (CI: 0.609, 0.828)
#
# Saved artifacts:
# - Model:   saved_models_2/2visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/2visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/2visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models_2/2visit_MCI_AD_report_AD.txt
#
# ============================================================
# === Running grid search for 3visit_CN_MCI (MCI) ===
# ============================================================
# No MMSE NaN values found; skipping MMSE imputation.
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 496 -> 914 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       115
#            1       0.50      0.50      0.50        10
#
#     accuracy                           0.92       125
#    macro avg       0.73      0.73      0.73       125
# weighted avg       0.92      0.92      0.92       125
#
#
# ROC AUC Score: 0.9330
# SMOTE resampling: 496 -> 914 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       115
#            1       0.50      0.50      0.50        10
#
#     accuracy                           0.92       125
#    macro avg       0.73      0.73      0.73       125
# weighted avg       0.92      0.92      0.92       125
#
#
# ROC AUC Score: 0.9330
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.920 (CI: 0.864, 0.960)
# - Precision (macro): 0.728 (CI: 0.566, 0.892)
# - Recall (macro): 0.728 (CI: 0.561, 0.899)
# - F1 (macro): 0.728 (CI: 0.565, 0.855)
# - ROC AUC: 0.933 (CI: 0.867, 0.987)
#
# Saved artifacts:
# - Model:   saved_models_2/3visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/3visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/3visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models_2/3visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 3visit_MCI_AD (AD) ===
# ============================================================
# No MMSE NaN values found; skipping MMSE imputation.
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.920 (CI: 0.864, 0.960)
# - Precision (macro): 0.728 (CI: 0.566, 0.892)
# - Recall (macro): 0.728 (CI: 0.561, 0.899)
# - F1 (macro): 0.728 (CI: 0.565, 0.855)
# - ROC AUC: 0.933 (CI: 0.867, 0.987)
#
# Saved artifacts:
# - Model:   saved_models_2/3visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/3visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/3visit_CN_MCI_imputer_MCI.pkl
# - Report:  saved_models_2/3visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 3visit_MCI_AD (AD) ===
# ============================================================
# No MMSE NaN values found; skipping MMSE imputation.
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 238 -> 340 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.65      0.61        17
#            1       0.85      0.81      0.83        43
#
#     accuracy                           0.77        60
#    macro avg       0.72      0.73      0.72        60
# weighted avg       0.78      0.77      0.77        60
#
#
# ROC AUC Score: 0.8057
# SMOTE resampling: 238 -> 340 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.65      0.61        17
#            1       0.85      0.81      0.83        43
#
#     accuracy                           0.77        60
#    macro avg       0.72      0.73      0.72        60
# weighted avg       0.78      0.77      0.77        60
#
#
# ROC AUC Score: 0.8057
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.767 (CI: 0.650, 0.867)
# - Precision (macro): 0.716 (CI: 0.585, 0.844)
# - Recall (macro): 0.731 (CI: 0.594, 0.854)
# - F1 (macro): 0.722 (CI: 0.587, 0.837)
# - ROC AUC: 0.806 (CI: 0.672, 0.923)
#
# Saved artifacts:
# - Model:   saved_models_2/3visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/3visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/3visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models_2/3visit_MCI_AD_report_AD.txt
#
# ============================================================
# === Running grid search for 4visit_CN_MCI (MCI) ===
# ============================================================
# Fitting MMSE imputer on training set (470 samples) with 16 covariates...
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.767 (CI: 0.650, 0.867)
# - Precision (macro): 0.716 (CI: 0.585, 0.844)
# - Recall (macro): 0.731 (CI: 0.594, 0.854)
# - F1 (macro): 0.722 (CI: 0.587, 0.837)
# - ROC AUC: 0.806 (CI: 0.672, 0.923)
#
# Saved artifacts:
# - Model:   saved_models_2/3visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/3visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/3visit_MCI_AD_imputer_AD.pkl
# - Report:  saved_models_2/3visit_MCI_AD_report_AD.txt
#
# ============================================================
# === Running grid search for 4visit_CN_MCI (MCI) ===
# ============================================================
# Fitting MMSE imputer on training set (470 samples) with 16 covariates...
# /Users/aeg00011/Desktop/AD-Research/AD-Early-Prediction/.venv/lib/python3.11/site-packages/sklearn/impute/_iterative.py:895: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# MMSE imputation complete (train fit, test transformed).
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 470 -> 880 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       111
#            1       0.33      0.14      0.20         7
#
#     accuracy                           0.93       118
#    macro avg       0.64      0.56      0.58       118
# weighted avg       0.91      0.93      0.92       118
#
#
# ROC AUC Score: 0.9524
# SMOTE resampling: 470 -> 880 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       111
#            1       0.33      0.14      0.20         7
#
#     accuracy                           0.93       118
#    macro avg       0.64      0.56      0.58       118
# weighted avg       0.91      0.93      0.92       118
#
#
# ROC AUC Score: 0.9524
# Bootstrap: valid=1000, total_attempts=1001, skipped=1 (1000/1001)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1001):
# - Accuracy: 0.932 (CI: 0.890, 0.975)
# - Precision (macro): 0.641 (CI: 0.457, 0.978)
# - Recall (macro): 0.562 (CI: 0.482, 0.737)
# - F1 (macro): 0.582 (CI: 0.473, 0.762)
# - ROC AUC: 0.952 (CI: 0.910, 0.985)
#
# Saved artifacts:
# - Model:   saved_models_2/4visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/4visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/4visit_CN_MCI_imputer_MCI.pkl
# - MMSE Imputer: saved_models_2/4visit_CN_MCI_mmse_imputer_MCI.pkl
# Bootstrap: valid=1000, total_attempts=1001, skipped=1 (1000/1001)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1001):
# - Accuracy: 0.932 (CI: 0.890, 0.975)
# - Precision (macro): 0.641 (CI: 0.457, 0.978)
# - Recall (macro): 0.562 (CI: 0.482, 0.737)
# - F1 (macro): 0.582 (CI: 0.473, 0.762)
# - ROC AUC: 0.952 (CI: 0.910, 0.985)
#
# Saved artifacts:
# - Model:   saved_models_2/4visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/4visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/4visit_CN_MCI_imputer_MCI.pkl
# - MMSE Imputer: saved_models_2/4visit_CN_MCI_mmse_imputer_MCI.pkl
# - Report:  saved_models_2/4visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 4visit_MCI_AD (AD) ===
# ============================================================
# Fitting MMSE imputer on training set (192 samples) with 16 covariates...
# - Report:  saved_models_2/4visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 4visit_MCI_AD (AD) ===
# ============================================================
# Fitting MMSE imputer on training set (192 samples) with 16 covariates...
# MMSE imputation complete (train fit, test transformed).
# MMSE imputation complete (train fit, test transformed).
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 192 -> 326 training samples
# SMOTE resampling: 192 -> 326 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.29      0.29      0.29         7
#            1       0.88      0.88      0.88        42
#
#     accuracy                           0.80        49
#    macro avg       0.58      0.58      0.58        49
# weighted avg       0.80      0.80      0.80        49
#
#
# ROC AUC Score: 0.7653
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.29      0.29      0.29         7
#            1       0.88      0.88      0.88        42
#
#     accuracy                           0.80        49
#    macro avg       0.58      0.58      0.58        49
# weighted avg       0.80      0.80      0.80        49
#
#
# ROC AUC Score: 0.7653
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.796 (CI: 0.673, 0.898)
# - Precision (macro): 0.583 (CI: 0.420, 0.790)
# - Recall (macro): 0.583 (CI: 0.423, 0.798)
# - F1 (macro): 0.583 (CI: 0.424, 0.751)
# - ROC AUC: 0.765 (CI: 0.605, 0.906)
#
# Saved artifacts:
# - Model:   saved_models_2/4visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/4visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/4visit_MCI_AD_imputer_AD.pkl
# - MMSE Imputer: saved_models_2/4visit_MCI_AD_mmse_imputer_AD.pkl
# - Report:  saved_models_2/4visit_MCI_AD_report_AD.txt
#
# ============================================================
# === Running grid search for 5visit_CN_MCI (MCI) ===
# ============================================================
# Fitting MMSE imputer on training set (380 samples) with 16 covariates...
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.796 (CI: 0.673, 0.898)
# - Precision (macro): 0.583 (CI: 0.420, 0.790)
# - Recall (macro): 0.583 (CI: 0.423, 0.798)
# - F1 (macro): 0.583 (CI: 0.424, 0.751)
# - ROC AUC: 0.765 (CI: 0.605, 0.906)
#
# Saved artifacts:
# - Model:   saved_models_2/4visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/4visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/4visit_MCI_AD_imputer_AD.pkl
# - MMSE Imputer: saved_models_2/4visit_MCI_AD_mmse_imputer_AD.pkl
# - Report:  saved_models_2/4visit_MCI_AD_report_AD.txt
#
# ============================================================
# === Running grid search for 5visit_CN_MCI (MCI) ===
# ============================================================
# Fitting MMSE imputer on training set (380 samples) with 16 covariates...
# MMSE imputation complete (train fit, test transformed).
# MMSE imputation complete (train fit, test transformed).
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 380 -> 598 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93        75
#            1       0.78      0.70      0.74        20
#
#     accuracy                           0.89        95
#    macro avg       0.85      0.82      0.84        95
# weighted avg       0.89      0.89      0.89        95
#
#
# ROC AUC Score: 0.8853
# SMOTE resampling: 380 -> 598 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93        75
#            1       0.78      0.70      0.74        20
#
#     accuracy                           0.89        95
#    macro avg       0.85      0.82      0.84        95
# weighted avg       0.89      0.89      0.89        95
#
#
# ROC AUC Score: 0.8853
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.895 (CI: 0.832, 0.947)
# - Precision (macro): 0.850 (CI: 0.737, 0.938)
# - Recall (macro): 0.823 (CI: 0.710, 0.923)
# - F1 (macro): 0.836 (CI: 0.723, 0.916)
# - ROC AUC: 0.885 (CI: 0.769, 0.968)
#
# Saved artifacts:
# - Model:   saved_models_2/5visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/5visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/5visit_CN_MCI_imputer_MCI.pkl
# Bootstrap: valid=1000, total_attempts=1000, skipped=0 (1000/1000)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1000):
# - Accuracy: 0.895 (CI: 0.832, 0.947)
# - Precision (macro): 0.850 (CI: 0.737, 0.938)
# - Recall (macro): 0.823 (CI: 0.710, 0.923)
# - F1 (macro): 0.836 (CI: 0.723, 0.916)
# - ROC AUC: 0.885 (CI: 0.769, 0.968)
#
# Saved artifacts:
# - Model:   saved_models_2/5visit_CN_MCI_model_MCI.pkl
# - Scaler:  saved_models_2/5visit_CN_MCI_scaler_MCI.pkl
# - Imputer: saved_models_2/5visit_CN_MCI_imputer_MCI.pkl
# - MMSE Imputer: saved_models_2/5visit_CN_MCI_mmse_imputer_MCI.pkl
# - Report:  saved_models_2/5visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 5visit_MCI_AD (AD) ===
# ============================================================
# Fitting MMSE imputer on training set (112 samples) with 16 covariates...
# - MMSE Imputer: saved_models_2/5visit_CN_MCI_mmse_imputer_MCI.pkl
# - Report:  saved_models_2/5visit_CN_MCI_report_MCI.txt
#
# ============================================================
# === Running grid search for 5visit_MCI_AD (AD) ===
# ============================================================
# Fitting MMSE imputer on training set (112 samples) with 16 covariates...
# MMSE imputation complete (train fit, test transformed).
# MMSE imputation complete (train fit, test transformed).
# Using StratifiedKFold with n_splits=5
# Using StratifiedKFold with n_splits=5
# SMOTE resampling: 112 -> 184 training samples
# SMOTE resampling: 112 -> 184 training samples
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44         5
#            1       0.88      0.92      0.90        24
#
#     accuracy                           0.83        29
#    macro avg       0.69      0.66      0.67        29
# weighted avg       0.81      0.83      0.82        29
#
#
# ROC AUC Score: 0.9167
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44         5
#            1       0.88      0.92      0.90        24
#
#     accuracy                           0.83        29
#    macro avg       0.69      0.66      0.67        29
# weighted avg       0.81      0.83      0.82        29
#
#
# ROC AUC Score: 0.9167
# Bootstrap: valid=1000, total_attempts=1004, skipped=4 (1000/1004)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1004):
# - Accuracy: 0.828 (CI: 0.655, 0.966)
# - Precision (macro): 0.690 (CI: 0.407, 0.963)
# - Recall (macro): 0.658 (CI: 0.429, 0.946)
# - F1 (macro): 0.671 (CI: 0.431, 0.879)
# - ROC AUC: 0.917 (CI: 0.783, 1.000)
#
# Saved artifacts:
# - Model:   saved_models_2/5visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/5visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/5visit_MCI_AD_imputer_AD.pkl
# - MMSE Imputer: saved_models_2/5visit_MCI_AD_mmse_imputer_AD.pkl
# - Report:  saved_models_2/5visit_MCI_AD_report_AD.txt
# Bootstrap: valid=1000, total_attempts=1004, skipped=4 (1000/1004)
#
# Bootstrap 95% CI (n=1000, valid_samples=1000/1004):
# - Accuracy: 0.828 (CI: 0.655, 0.966)
# - Precision (macro): 0.690 (CI: 0.407, 0.963)
# - Recall (macro): 0.658 (CI: 0.429, 0.946)
# - F1 (macro): 0.671 (CI: 0.431, 0.879)
# - ROC AUC: 0.917 (CI: 0.783, 1.000)
#
# Saved artifacts:
# - Model:   saved_models_2/5visit_MCI_AD_model_AD.pkl
# - Scaler:  saved_models_2/5visit_MCI_AD_scaler_AD.pkl
# - Imputer: saved_models_2/5visit_MCI_AD_imputer_AD.pkl
# - MMSE Imputer: saved_models_2/5visit_MCI_AD_mmse_imputer_AD.pkl
# - Report:  saved_models_2/5visit_MCI_AD_report_AD.txt
